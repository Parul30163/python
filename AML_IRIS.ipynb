# %% [markdown]
# <a href="https://colab.research.google.com/github/Parul30163/python/blob/main/AML_IRIS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import  numpy as np
import pandas as pd
from sklearn import datasets
iris=datasets.load_iris(as_frame=True)

# %%
iris= iris.frame

# %%
iris.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
df['target'] = iris.target

# Map targets to target names
target_names = {
    0:'setosa',
    1:'versicolor',
    2:'virginica'
}

df['target_names'] = df['target'].map(target_names)
df.head(95)
# Out:
#     sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                 5.1               3.5                1.4               0.2
# 1                 4.9               3.0                1.4               0.2
# 2                 4.7               3.2                1.3               0.2
# 3                 4.6               3.1                1.5               0.2
# 4                 5.0               3.6                1.4               0.2
# ..                ...               ...                ...               ...
# 90                5.5               2.6                4.4               1.2
# 91                6.1               3.0                4.6               1.4
# 92                5.8               2.6                4.0               1.2
# 93                5.0               2.3                3.3               1.0
# 94                5.6               2.7                4.2               1.3
#
#     target target_names
# ...

# %%
# remove spaces from column name
iris.columns = iris.columns.str.replace(' ', '_')
iris.head()
# Out:
#    sepal_length_(cm)  sepal_width_(cm)  petal_length_(cm)  petal_width_(cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
iris.describe
# Out:
# <bound method NDFrame.describe of      sepal_length_(cm)  sepal_width_(cm)  petal_length_(cm)  petal_width_(cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# ...

# %%
import numpy as np
import pandas as pd
import sklearn
from sklearn import datasets
iris=datasets.load_iris()
iris=pd.DataFrame(data=np.c_[iris['data'],iris['target']],columns=iris['feature_names']+['species'])
#replace the values with the class labels
iris.species=np.where(iris.species==0.0,'setosa',np.where(iris.species==1.0,'versicolor','virginica'))
print(iris)
#  remove s[paces from column name]
iris_columns=iris.columns.str.replace(' ','')
iris.describe()
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#        species
# 0       setosa
# ...

# %%
import matplotlib.pyplot as plt
plt.plot(iris.species)
plt.show()

# %%
plt.figure(figsize=(15,8))
iris.hist()
plt.suptitle('Histogram of Iris Dataset',fontsize=12)
plt.tight_layout(pad=1)
plt.show()

# %%
iris.boxplot()
plt.title('BAR',fontsize=16)
plt.tight_layout(pad=1)
plt.show()

# %%
iris['species'].value_counts().plot(kind='bar') #bar type graph
# Out:
# <Axes: xlabel='species'>
