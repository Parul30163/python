# %% [markdown]
# <a href="https://colab.research.google.com/github/Parul30163/python/blob/main/internshala5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('/content/1. Regression - Module - (Housing Prices).csv')

# %%
len(df['Latitude'].unique())
# Out:
# 5035

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   ID                                         21613 non-null  int64
#  1   Date House was Sold                        21613 non-null  object
#  2   Sale Price                                 21609 non-null  float64
#  3   No of Bedrooms                             21613 non-null  int64
#  4   No of Bathrooms                            21609 non-null  float64
#  5   Flat Area (in Sqft)                        21604 non-null  float64
#  6   Lot Area (in Sqft)                         21604 non-null  float64
#  7   No of Floors                               21613 non-null  float64
#  8   Waterfront View                            21613 non-null  object
#  9   No of Times Visited                        2124 non-null   object
# ...

# %%
numerical_columns= ['No of Bathrooms','Flat Area (in Sqft)','Lot Area (in Sqft)',
                   'Area of the House from Basement (in Sqft)','Latitude','Longitude',
                   'Living Area after Renovation (in Sqft)']

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(missing_values =np.nan,strategy='median')
df[numerical_columns]=imputer.fit_transform(df[numerical_columns])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   ID                                         21613 non-null  int64
#  1   Date House was Sold                        21613 non-null  object
#  2   Sale Price                                 21609 non-null  float64
#  3   No of Bedrooms                             21613 non-null  int64
#  4   No of Bathrooms                            21613 non-null  float64
#  5   Flat Area (in Sqft)                        21613 non-null  float64
#  6   Lot Area (in Sqft)                         21613 non-null  float64
#  7   No of Floors                               21613 non-null  float64
#  8   Waterfront View                            21613 non-null  object
#  9   No of Times Visited                        2124 non-null   object
# ...

# %%
imputer = SimpleImputer(missing_values =np.nan,strategy='most_frequent')
df['Zipcode']=imputer.fit_transform(df[['Zipcode']])

# %%
column =df['Zipcode'].values.reshape(-1,1)
column.shape
# Out:
# (21613, 1)

# %%
column =df['Zipcode'].values.reshape(-1,1)
imputer = SimpleImputer(missing_values =np.nan,strategy='most_frequent')
df['Zipcode']=imputer.fit_transform(column)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   ID                                         21613 non-null  int64
#  1   Date House was Sold                        21613 non-null  object
#  2   Sale Price                                 21609 non-null  float64
#  3   No of Bedrooms                             21613 non-null  int64
#  4   No of Bathrooms                            21613 non-null  float64
#  5   Flat Area (in Sqft)                        21613 non-null  float64
#  6   Lot Area (in Sqft)                         21613 non-null  float64
#  7   No of Floors                               21613 non-null  float64
#  8   Waterfront View                            21613 non-null  object
#  9   No of Times Visited                        2124 non-null   object
# ...

# %%
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings(action ='ignore')

# %%
df.head()
# Out:
#            ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0  7129300520     14 October 2017    221900.0               3
# 1  6414100192    14 December 2017    538000.0               3
# 2  5631500400    15 February 2016    180000.0               2
# 3  2487200875    14 December 2017    604000.0               4
# 4  1954400510    15 February 2016    510000.0               3
#
#    No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0             1.00               1180.0              5650.0           1.0
# 1             2.25               2570.0              7242.0           2.0
# 2             1.00                770.0             10000.0           1.0
# 3             3.00               1960.0              5000.0           1.0
# 4             2.00               1680.0              8080.0           1.0
#
#   Waterfront View No of Times Visited  ... Overall Grade  \
# 0              No                 NaN  ...             7
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   ID                                         21613 non-null  int64
#  1   Date House was Sold                        21613 non-null  object
#  2   Sale Price                                 21609 non-null  float64
#  3   No of Bedrooms                             21613 non-null  int64
#  4   No of Bathrooms                            21613 non-null  float64
#  5   Flat Area (in Sqft)                        21613 non-null  float64
#  6   Lot Area (in Sqft)                         21613 non-null  float64
#  7   No of Floors                               21613 non-null  float64
#  8   Waterfront View                            21613 non-null  object
#  9   No of Times Visited                        2124 non-null   object
# ...

# %%
df['No of Times Visited'].unique()
# Out:
# array([nan, 'Thrice', 'Four', 'Twice', 'Once'], dtype=object)

# %%
mapping = {'None':0,'Once':1,'Twice':2,'Thrice':3,'Four':4}
df['No of Times Visited']=df['No of Times Visited'].map(mapping)

# %%
df['No of Times Visited'].unique()
# Out:
# array([nan,  3.,  4.,  2.,  1.])

# %%
df['Ever Renovate']=np.where (df['Renovated Year']==0, 'No','Yes')

# %%
df.head(10)
# Out:
#            ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0  7129300520     14 October 2017    221900.0               3
# 1  6414100192    14 December 2017    538000.0               3
# 2  5631500400    15 February 2016    180000.0               2
# 3  2487200875    14 December 2017    604000.0               4
# 4  1954400510    15 February 2016    510000.0               3
# 5  7237550310         14 May 2017   1230000.0               4
# 6  1321400060        14 June 2017    257500.0               3
# 7  2008000270     15 January 2016    291850.0               3
# 8  2414600126       15 April 2016    229500.0               3
# 9  3793500160       15 March 2016    323000.0               3
#
#    No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0             1.00               1180.0              5650.0           1.0
# 1             2.25               2570.0              7242.0           2.0
# ...

# %%
df['Purchase Year']= pd.DatetimeIndex(df['Date House was Sold']).year

# %%
df['Year Since Renovation']=np.where(df['Ever Renovate']=='Yes',abs(df['Purchase Year']-df['Renovated Year']),0)

# %%
df.head()
# Out:
#            ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0  7129300520     14 October 2017    221900.0               3
# 1  6414100192    14 December 2017    538000.0               3
# 2  5631500400    15 February 2016    180000.0               2
# 3  2487200875    14 December 2017    604000.0               4
# 4  1954400510    15 February 2016    510000.0               3
#
#    No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0             1.00               1180.0              5650.0           1.0
# 1             2.25               2570.0              7242.0           2.0
# 2             1.00                770.0             10000.0           1.0
# 3             3.00               1960.0              5000.0           1.0
# 4             2.00               1680.0              8080.0           1.0
#
#   Waterfront View  No of Times Visited  ... Age of House (in Years)  \
# 0              No                  NaN  ...                      63
# ...

# %%
df.drop(columns=['Purchase Year','Date House was Sold','Renovated Year'],inplace=True)

# %%
df.head()
# Out:
#            ID  Sale Price  No of Bedrooms  No of Bathrooms  \
# 0  7129300520    221900.0               3             1.00
# 1  6414100192    538000.0               3             2.25
# 2  5631500400    180000.0               2             1.00
# 3  2487200875    604000.0               4             3.00
# 4  1954400510    510000.0               3             2.00
#
#    Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors Waterfront View  \
# 0               1180.0              5650.0           1.0              No
# 1               2570.0              7242.0           2.0              No
# 2                770.0             10000.0           1.0              No
# 3               1960.0              5000.0           1.0              No
# 4               1680.0              8080.0           1.0              No
#
#    No of Times Visited Condition of the House  ...  \
# 0                  NaN                   Fair  ...
# 1                  NaN                   Fair  ...
# ...

# %% [markdown]
# Correlation is a measure of dependence or accociation between two  variable ie.
# how does one variable change with change in other///rfers to how close two variables are to have a linear relationship with each other

# %%
import pandas as pd
tf=pd.read_csv('/content/Raw_Housing_Prices3.csv')

# %%
tf.head()
# Out:
#            ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0  7129300520     14 October 2017    221900.0               3
# 1  6414100192    14 December 2017    538000.0               3
# 2  5631500400    15 February 2016    180000.0               2
# 3  2487200875    14 December 2017    604000.0               4
# 4  1954400510    15 February 2016    510000.0               3
#
#    No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0             1.00               1180.0              5650.0           1.0
# 1             2.25               2570.0              7242.0           2.0
# 2             1.00                770.0             10000.0           1.0
# 3             3.00               1960.0              5000.0           1.0
# 4             2.00               1680.0              8080.0           1.0
#
#   Waterfront View No of Times Visited  ... Overall Grade  \
# 0              No                 NaN  ...             7
# ...

# %%
tf['Sale Price'].corr(tf['Flat Area (in Sqft)'])
# Out:
# 0.6951704258420669

# %%
import numpy as np

# %%
np.corrcoef(tf['Sale Price'],tf['Flat Area (in Sqft)'])
# Out:
# array([[1.        , 0.69517043],
#        [0.69517043, 1.        ]])

# %%
#tf.drop(columns =['Id']).corr()

# %%
tf['Flat Area (in Sqft)'].corr(tf['Sale Price'])
# Out:
# 0.6951704258420669

# %%
np.corrcoef(tf['Flat Area (in Sqft)'],tf['Sale Price'])
# Out:
# array([[1.        , 0.69517043],
#        [0.69517043, 1.        ]])
